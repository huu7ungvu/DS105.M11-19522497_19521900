# %%
import pandas as pd
import numpy as np

# %%
# Đọc dữ liệu
data=pd.read_csv('final_result.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 34 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Country Name                                                                                                      204 non-null    object
#  1   Population, total [SP.POP.TOTL]                                                                                   204 non-null    int64
#  2   Population, male (% of total population) [SP.POP.TOTL.MA.ZS]                                                      193 non-null    float64
#  3   Population, female (% of total population) [SP.POP.TOTL.FE.ZS]                                                    193 non-null    float64
# ...

# %%
data.head(5)
# Out:
#   Country Name  Population, total [SP.POP.TOTL]  \
# 0  Afghanistan                         38041757
# 1      Albania                          2854191
# 2      Algeria                         43053054
# 3      Andorra                            77146
# 4       Angola                         31825299
#
#    Population, male (% of total population) [SP.POP.TOTL.MA.ZS]  \
# 0                                          51.337605
# 1                                          50.913894
# 2                                          50.518288
# 3                                                NaN
# 4                                          49.472525
#
#    Population, female (% of total population) [SP.POP.TOTL.FE.ZS]  \
# 0                                          48.662395
# 1                                          49.086106
# 2                                          49.481712
# 3                                                NaN
# 4                                          50.527475
#
# ...

# %%
data.dtypes
# Out:
# Country Name                                                                                                         object
# Population, total [SP.POP.TOTL]                                                                                       int64
# Population, male (% of total population) [SP.POP.TOTL.MA.ZS]                                                        float64
# Population, female (% of total population) [SP.POP.TOTL.FE.ZS]                                                      float64
# Population growth (annual %) [SP.POP.GROW]                                                                          float64
# Population density (people per sq. km of land area) [EN.POP.DNST]                                                   float64
# Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]                                                    float64
# ...

# %%
data.isna().sum()
# Out:
# Country Name                                                                                                         0
# Population, total [SP.POP.TOTL]                                                                                      0
# Population, male (% of total population) [SP.POP.TOTL.MA.ZS]                                                        11
# Population, female (% of total population) [SP.POP.TOTL.FE.ZS]                                                      11
# Population growth (annual %) [SP.POP.GROW]                                                                           0
# Population density (people per sq. km of land area) [EN.POP.DNST]                                                    1
# Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]                                                    11
# Population ages 15-64 (% of total population) [SP.POP.1564.TO.ZS]                                                   11
# ...

# %%
for i in data.columns.values:
    if (i not in ['Country Name','Region']):
        data[i]=data[i].astype('float')

# %%
data.describe()
# Out:
#        Population, total [SP.POP.TOTL]  \
# count                     1.890000e+02
# mean                      4.007002e+07
# std                       1.469048e+08
# min                       5.283400e+04
# 25%                       2.125267e+06
# 50%                       8.776119e+06
# 75%                       2.916192e+07
# max                       1.397715e+09
#
#        Population, male (% of total population) [SP.POP.TOTL.MA.ZS]  \
# count                                         185.000000
# mean                                           50.152037
# std                                             3.436199
# min                                            45.604820
# 25%                                            49.081430
# 50%                                            49.745947
# 75%                                            50.379458
# max                                            75.334305
#
#        Population, female (% of total population) [SP.POP.TOTL.FE.ZS]  \
# ...

# %%
data_c=data_copy[['Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]',
       'Population ages 15-64 (% of total population) [SP.POP.1564.TO.ZS]',
       'Population ages 65 and above (% of total population) [SP.POP.65UP.TO.ZS]']]

# %%
data_c=data_c.astype('float')

# %%
data_c.dtypes

# %%
data_c.isna().sum()

# %%
data_c['Population Structure']=pd.Series(np.random.randint(len(data_c.index)), index=data_c.index)

# %%
for i in data_c.index:
    if (data_c['Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]'][i]>=35 and data_c['Population ages 65 and above (% of total population) [SP.POP.65UP.TO.ZS]'][i]<=7):
        data_c['Population Structure'][i]='Old'
    else:
        data_c['Population Structure'][i]='Young'

# %%
data_c.shape
