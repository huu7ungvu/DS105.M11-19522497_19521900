# %%
import pandas as pd

# %%
data=pd.read_csv(r'final_data.csv')

# %%
data.head(5)
# Out:
#    Time    Country Name  Population, total Population Structure  \
# 0  2000     Afghanistan         20779957.0                Young
# 1  2000         Albania          3089027.0                  Old
# 2  2000         Algeria         31042238.0                  Old
# 3  2000  American Samoa            57816.0                  NaN
# 4  2000         Andorra            65390.0                  NaN
#
#   Population growth  \
# 0               2-3
# 1                -0
# 2               1-2
# 3               1-2
# 4               1-2
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                              11.65
# 1                                              16.58
# 2                                              29.77
# 3                                                NaN
# 4                                                NaN
#
#    Labor force, total  Life expectancy index  \
# 0           5071019.0                  0.551
# ...
